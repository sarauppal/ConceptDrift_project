# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import GaussianNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn import model_selection
from sklearn.svm import SVC
import pylab
import time
import random
import matplotlib.pyplot as plt

# %% [markdown]
# # Monitor marginal density vs accuracy for support vector classifier

# %%
df = pd.read_csv('data/sea.csv', names = ['feature1','feature2','feature3','label'])

# %%
df1  = df[:15000]
df2  = df[15000:30000]
df3  = df[30000:45000]
df4  = df[45000:60000]

# %%
X = df1[['feature1', 'feature2', 'feature3']].values
y = df1['label'].values

# %% [markdown]
# ## Data set has four concepts

# %% [markdown]
# Look for the changes in decision boundary

# %%
nrow = 2
ncol = 2
df_list = [df1 ,df2, df3, df4]
fig, axes = plt.subplots(nrow, ncol)
plt.subplots_adjust(left=None, bottom=None, right=None, top=None, wspace=None, hspace=0.3)
# plot counter
count=0
for r in range(nrow):
    for c in range(ncol):

        df_list[count].plot(ax=axes[r,c],kind = 'scatter' , 
                            x= 'feature2' , y='feature3' , 
                            c = 'label', colormap='viridis' , 
                            figsize=(10,8), colorbar = False,
                           title = "Concept " + str(count+1))
        count+=1
plt.savefig('figs/concepts_SEA.png')

# %%
def calc_marginal_density(model,X,y):
    w = model.coef_
    w = w.reshape(X.shape[1],)
    b = model.intercept_
    dp = abs(np.dot(X,w)+b)
    rho  = np.round(np.array(dp<1).sum() / X.shape[0],7)
    return rho

# %%
def train_model(X,y):
    seed = 369
    test_size = 0.33
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=test_size, random_state=seed)
    model_new = SVC(kernel = 'linear')
    model_new.fit(X_train, y_train)
    y_pred = model_new.predict(X_test)
    accuracy = accuracy_score(y_test, y_pred)
    print("Accuracy after retraining: %.2f%%" % (accuracy * 100.0))
    return model_new,X_test

# %%
df1 = df[0:15000]
X1 = df1[['feature1', 'feature2', 'feature3']].values
y1 = df1['label'].values
# split data into train and test sets
seed = 9
test_size = 0.33
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=test_size, random_state=seed)
scoring = ['accuracy', 'precision_weighted', 'recall_weighted', 'f1_weighted', 'roc_auc']
# fit model no training data
model = SVC(kernel = 'linear')
model.fit(X1_train, y1_train)
print(model)
# Out:
# SVC(C=1.0, break_ties=False, cache_size=200, class_weight=None, coef0=0.0,
#     decision_function_shape='ovr', degree=3, gamma='scale', kernel='linear',
#     max_iter=-1, probability=False, random_state=None, shrinking=True,
#     tol=0.001, verbose=False)

# %%
kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=4369)
cv_results = model_selection.cross_validate(model, X1_train, y1_train, cv=kfold, scoring=scoring)
clf = model.fit(X1_train, y1_train)
cv_results
# Out:
# {'fit_time': array([1.6619997 , 1.90154648, 1.89012885, 2.19094706, 2.13409972]),
#  'score_time': array([0.0740006 , 0.07203341, 0.07799816, 0.0800786 , 0.0769968 ]),
#  'test_accuracy': array([0.88208955, 0.88557214, 0.89552239, 0.88557214, 0.89154229]),
#  'test_precision_weighted': array([0.8823885 , 0.88595913, 0.89665039, 0.88588119, 0.8916081 ]),
#  'test_recall_weighted': array([0.88208955, 0.88557214, 0.89552239, 0.88557214, 0.89154229]),
#  'test_f1_weighted': array([0.87980044, 0.88312537, 0.89344403, 0.8835353 , 0.8898171 ]),
#  'test_roc_auc': array([0.85579563, 0.87180952, 0.87744048, 0.87902388, 0.8924384 ])}

# %%
kfold = model_selection.KFold(n_splits=5, shuffle=True, random_state=4369)
cv_results = model_selection.cross_validate(model, X1_train, y1_train, cv=kfold, scoring=calc_marginal_density)
clf = model.fit(X1_train, y1_train)
cv_results
# Out:
# {'fit_time': array([1.82961202, 2.21624207, 2.07350683, 2.21300983, 2.17700076]),
#  'score_time': array([0.00099969, 0.00096178, 0.00100017, 0.00100088, 0.        ]),
#  'test_score': array([0.3751244, 0.3512438, 0.3701493, 0.3681592, 0.3860697])}

# %%
sigma_ref = cv_results['test_score'].std()

# %%
sigma_ref
# Out:
# 0.011310076785132813

# %% [markdown]
# ## Monitor marginal density with changing data set

# %%
# %matplotlib notebook
# import numpy as np
# import matplotlib.pyplot as plt

# %%
## Initiate model
df1 = df[0:15000]
X1 = df1[['feature1', 'feature2', 'feature3']].values
y1 = df1['label'].values
# split data into train and test sets
seed = 9
test_size = 0.33
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=test_size, random_state=seed)
# fit model no training data
# model = SVC(kernel = 'linear' , C = 2, probability = True)
model = SVC(kernel = 'linear')
model.fit(X1_train, y1_train)
y1_pred = model.predict(X1_test)
accuracy = accuracy_score(y1_test, y1_pred)
print("Initial model accuracy: %.2f%%" % (accuracy * 100.0))
# Out:
# Initial model accuracy: 88.65%

# %%
print('initial marginal density ' , calc_marginal_density(model,X1,y))
# Out:
# initial marginal density  0.3724667

# %%
batch_size = 1000
window_size = 10000
# fig = plt.figure(figsize=(10,20))
fig = plt.figure()
ax  = fig.add_subplot(111)
ax2=ax.twinx()
plt.ion()

fig.show()
fig.canvas.draw()

densities = []
acc = []
# rho_max = rho_min
for i in range(int((len(df)-1)/batch_size)+1):
    df_temp = df[(i*batch_size):((i*batch_size)+window_size)]
    X2 = df_temp[['feature1', 'feature2', 'feature3']].values
    y2 = df_temp['label'].values
    rho = calc_marginal_density(model,X2,y)
#     if  (rho > rho_max):
#         rho_max = rho
    
#     densities.append(rho_max -rho_min)
    densities.append(rho)
    y2_pred = model.predict(X2)
    acc.append((100*accuracy_score(y2, y2_pred)))
    ax.clear()
#     ax.set_xlim([0,int((len(df)-window_size)/batch_size)])
    ax.set_xlim([0,int((len(df)-window_size)/batch_size)])
    ax2.set_xlim([0,int((len(df)-window_size)/batch_size)])
    ax.set_ylim([0.35,0.4])
    ax2.set_ylim([50,100])
    ax.plot(range(len(densities)),densities, color = 'red')
    ax.set_ylabel("Marginal Density",color="red",fontsize=14)
    ax2.plot(range(len(acc)),acc, color = 'blue')
    ax2.set_ylabel("Accuracy (%)",color="blue",fontsize=14)

    fig.canvas.draw()
    plt.pause(0.0000001)
# Out:
# C:\Users\t910571\Anaconda3\lib\site-packages\ipykernel_launcher.py:9: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   if __name__ == '__main__':

# %%
fig = plt.figure()
ax  = fig.add_subplot(111)
ax2=ax.twinx()
ax.set_xlim([0,int((len(df)-window_size)/batch_size)])
ax2.set_xlim([0,int((len(df)-window_size)/batch_size)])
ax.set_ylim([0.35,0.40])
ax2.set_ylim([50,100])
ax.plot(range(len(densities)),densities, color = 'red')
ax.set_ylabel("Marginal Desity",color="red",fontsize=14)
ax2.plot(range(len(acc)),acc, color = 'blue')
ax2.set_ylabel("Accuracy (%)",color="blue",fontsize=14)
plt.savefig('figs/MD3_wo_intervention_SEA.png')
# Out:
# Text(0, 0.5, 'Accuracy (%)')

# %%
np.mean(acc)
# Out:
# 84.21816468253968

# %% [markdown]
# ## Monitor accuracy with intervention at $| \rho_{train} - \rho_{score} | > 2 * \sigma_{ref}$

# %%
batch_size = 1000
window_size = 10000
## Initiate model
df1 = df[0:15000]
X1 = df1[['feature1', 'feature2', 'feature3']].values
y1 = df1['label'].values
# split data into train and test sets
seed = 9
test_size = 0.33
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, test_size=test_size, random_state=seed)
# fit model no training data
model = SVC(kernel = 'linear')
model.fit(X1_train, y1_train)
y1_pred = model.predict(X1_test)
accuracy = accuracy_score(y1_test, y1_pred)
print("Initial model accuracy: %.2f%%" % (accuracy * 100.0))

rho_min = calc_marginal_density(model,X1,y)


# fig = plt.figure(figsize=(10,20))
fig = plt.figure()
ax  = fig.add_subplot(111)
ax2=ax.twinx()
plt.ion()

fig.show()
fig.canvas.draw()

densities = []
acc = []
for i in range(int((len(df)-window_size)/batch_size)+1):

    df_temp = df[(i*batch_size):((i*batch_size)+window_size)]
    X2 = df_temp[['feature1', 'feature2', 'feature3']].values
    y2 = df_temp['label'].values
#     PSIs.append(calculate_PSI(X1_test,df[i*batch_size,(i*batch_size)+window_size],model))
    rho = calc_marginal_density(model,X2,y)
    densities.append(rho)
    y2_pred = model.predict(X2)
#     print((100*accuracy_score(y2, y2_pred)))
    acc.append((100*accuracy_score(y2, y2_pred)))
    ax.clear()
    ax.set_xlim([0,int((len(df)-window_size)/batch_size)])
    ax2.set_xlim([0,int((len(df)-window_size)/batch_size)])
    ax.set_ylim([0.30,0.45])
    ax2.set_ylim([0.4,100])
    ax.plot(range(len(densities)),densities, color = 'red')
    ax.set_ylabel("Marginal Density",color="red",fontsize=14)
    ax2.plot(range(len(acc)),acc, color = 'blue')
    ax2.set_ylabel("Accuracy (%)",color="blue",fontsize=14)

    fig.canvas.draw()
    plt.pause(0.001)
    
    if abs(rho-rho_min) > (0.25*sigma_ref):
#         print("Condition met, retraining model")
        model,new_ref_df = train_model(X2,y2)
#         print("new PSI = ", calculate_PSI(X2,X2,model))
        X1_test = X2
#         rho_min = calc_marginal_density(model,X2,y)
# Out:
# Initial model accuracy: 88.65%
# C:\Users\t910571\Anaconda3\lib\site-packages\ipykernel_launcher.py:27: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
# Accuracy after retraining: 89.76%
# Accuracy after retraining: 88.82%
# Accuracy after retraining: 88.30%
# Accuracy after retraining: 88.33%
# Accuracy after retraining: 88.70%
# Accuracy after retraining: 87.70%
# Accuracy after retraining: 86.64%
# Accuracy after retraining: 86.94%
# Accuracy after retraining: 87.45%
# Accuracy after retraining: 89.61%
# Accuracy after retraining: 88.58%
# Accuracy after retraining: 89.39%
# Accuracy after retraining: 89.94%
# Accuracy after retraining: 88.82%
# Accuracy after retraining: 86.67%
# Accuracy after retraining: 85.36%
# Accuracy after retraining: 83.70%
# Accuracy after retraining: 83.67%
# Accuracy after retraining: 82.55%
# Accuracy after retraining: 82.88%
# Accuracy after retraining: 85.09%
# Accuracy after retraining: 86.58%
# Accuracy after retraining: 88.39%
# Accuracy after retraining: 88.73%
# Accuracy after retraining: 89.97%
# Accuracy after retraining: 86.12%
# Accuracy after retraining: 84.48%
# Accuracy after retraining: 83.94%
# Accuracy after retraining: 83.70%
# Accuracy after retraining: 84.18%
# Accuracy after retraining: 86.09%
# Accuracy after retraining: 85.73%
# Accuracy after retraining: 88.12%
# Accuracy after retraining: 90.21%
# Accuracy after retraining: 89.55%
# Accuracy after retraining: 89.39%
# Accuracy after retraining: 90.00%
# Accuracy after retraining: 89.48%
# Accuracy after retraining: 89.48%

# %%
fig = plt.figure()
ax  = fig.add_subplot(111)
ax2=ax.twinx()
ax.set_xlim([0,int((len(df)-window_size)/batch_size)])
ax2.set_xlim([0,int((len(df)-window_size)/batch_size)])
ax.set_ylim([0.30,0.45])
ax2.set_ylim([0.4,100])
ax.plot(range(len(densities)),densities, color = 'red')
ax.set_ylabel("Marginal Density",color="red",fontsize=14)
ax2.plot(range(len(acc)),acc, color = 'blue')
ax2.set_ylabel("Accuracy (%)",color="blue",fontsize=14)
# Out:
# Text(0, 0.5, 'Accuracy (%)')

# %%
np.mean(acc)
# Out:
# 87.36333333333333

# %%
acc
# Out:
# [89.01,
#  88.9,
#  88.86,
#  89.05,
#  88.77000000000001,
#  88.52,
#  87.89,
#  87.39,
#  87.5,
#  86.61,
#  86.02,
#  85.75,
#  85.48,
#  85.21,
#  87.25,
#  87.83999999999999,
#  89.44,
#  89.23,
#  89.17,
#  89.25999999999999,
#  88.99000000000001,
#  87.68,
#  85.65,
#  84.57000000000001,
#  83.64,
#  83.31,
#  83.35000000000001,
#  84.17999999999999,
#  85.3,
#  86.82,
#  89.29,
#  89.53999999999999,
#  89.86,
#  89.69,
#  89.53,
#  89.56,
#  88.19,
#  86.94,
#  85.14,
#  84.07,
#  83.66,
#  84.05,
#  84.50999999999999,
#  86.06,
#  87.31,
#  89.13,
#  89.85,
#  89.66,
#  89.44,
#  89.5,
#  89.91]
